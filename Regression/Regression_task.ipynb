# %% [markdown]
# #Connecting libraries

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics as sklearn_metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor    
import missingno as msno
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
import seaborn

# %%
# !pip install -U keras-tuner

from keras_tuner import RandomSearch, Hyperband, BayesianOptimization
# Out:
# Collecting keras-tuner
#   Using cached keras_tuner-1.1.3-py3-none-any.whl (135 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: tensorboard in c:\programdata\anaconda3\lib\site-packages (from keras-tuner) (2.11.0)
# Collecting kt-legacy
#   Using cached kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from keras-tuner) (8.2.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from keras-tuner) (1.21.5)
# Requirement already satisfied: traitlets>=5 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.4.4)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (61.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->keras-tuner) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (2.0.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.2.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from asttokens->stack-data->ipython->keras-tuner) (1.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.33.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (3.19.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.42.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras-tuner) (2.0.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.1.3 kt-legacy-1.0.4

# %% [markdown]
# #Loading dataset

# %%
train = pd.read_csv("C:\\Users\\Dexp\\Desktop\\train.csv")
test = pd.read_csv("C:\\Users\\Dexp\\Desktop\\test.csv")

# %%
print(len(train))
print(len(test))
# Out:
# 47439
# 31626

# %%
print(train.duplicated().sum())
print(test.duplicated().sum())
# Out:
# 0
# 0

# %%
train['Year built'].unique()
# Out:
# array([1969., 1926., 1958., 1947.,   nan, 1905., 2005., 2001., 1973.,
#        1953., 2002., 1923., 2018., 1986., 1939., 1949., 1988., 1922.,
#        1920., 1952., 1938., 1956., 1977., 2019., 1970., 1957., 2003.,
#        1941., 1928., 1936., 1991., 1929., 1950., 1972., 1965., 1933.,
#        1964., 1968., 1924.,    0., 2009., 1966., 1963., 1975., 1948.,
#        1960., 1955., 1998., 2015., 1942., 1927., 1914., 1940., 2014.,
#        1974., 1959., 1990., 1921., 1997., 2000., 1930., 1978., 1945.,
#        1900., 1980., 1979., 1912., 2008., 1962., 1989., 1967., 1976.,
#        1925., 1985., 2016., 1987., 1860., 1904., 1935., 1918., 1982.,
#        1995., 1946., 1911., 1909., 1971., 1961., 1943., 1983., 2006.,
#        1951., 1910., 2007., 2004., 1984., 1981., 1934., 2011., 1907.,
#        1903., 1913., 2017., 1915., 1999., 1908., 1954., 1868., 2010.,
#        1944., 1994., 1931., 1906., 1902., 1937., 1992., 1919., 2013.,
#        1895., 1996., 1885., 1852., 1890., 1901., 2020., 2012., 1916.,
#        1993., 1897., 1917., 1888., 1932., 1883., 1880., 1898., 1894.,
#        1892., 1889., 1893., 1850., 1873., 1875., 1886., 2021., 1879.,
#        1896., 1884., 1891., 1878., 1882., 1870.,   19., 1899., 1855.,
#        1871., 1865., 1887., 2281., 1872., 1881., 1848., 1858., 1471.,
#        1861., 1876., 9999.])

# %%
train[train['Year built'] == 9999]
# Out:
#           Id      Address  Sold Price  \
# 46898  46898  156 20th St    492000.0
#
#                                                  Summary          Type  \
# 46898  Property went to escrow before going on the ML...  SingleFamily
#
#        Year built                    Heating Cooling  \
# 46898      9999.0  See Remarks, Fireplace(s)    None
#
#                                   Parking  Lot Bedrooms  Bathrooms  \
# 46898  Carport, Driveway, Covered, Gravel  NaN        2        2.0
#
#        Full bathrooms  Total interior livable area  Total spaces  \
# 46898             2.0                        962.0           1.0
#
#        Garage spaces     Region          Elementary School  \
# 46898            1.0  San Diego  Sherman Elementary School
#
#        Elementary School Score  Elementary School Distance  \
# 46898                      5.0                         0.2
#
#                                Middle School  Middle School Score  \
# 46898  Roosevelt International Middle School                  5.0
#
#        Middle School Distance           High School  High School Score  \
# 46898                     2.1  e3 Civic High School                5.0
#
#        High School Distance Flooring           Heating features  \
# 46898                   0.6      NaN  See Remarks, Fireplace(s)
#
#       Cooling features Appliances included           Laundry features  \
# 46898             None                 NaN  Gas Dryer Hookup, Outside
#
#                          Parking features  Tax assessed value  \
# 46898  Carport, Driveway, Covered, Gravel             96125.0
#
#        Annual tax amount   Listed On  Listed Price Last Sold On  \
# 46898             1098.0  2020-12-08      509000.0          NaN
#
#        Last Sold Price       City    Zip State
# 46898              NaN  San Diego  92102    CA

# %%
train.isna().sum(axis = 0)
# Out:
# Id                                 0
# Address                            0
# Sold Price                         0
# Summary                          350
# Type                               0
# Year built                      1045
# Heating                         6465
# Cooling                        10622
# Parking                          908
# Lot                            14181
# Bedrooms                        2872
# Bathrooms                       3465
# Full bathrooms                  7865
# Total interior livable area     2526
# Total spaces                     916
# Garage spaces                    917
# Region                             2
# Elementary School               4742
# Elementary School Score         4896
# Elementary School Distance      4742
# Middle School                  16704
# Middle School Score            16705
# Middle School Distance         16704
# High School                     5000
# High School Score               5219
# High School Distance            5001
# Flooring                       11564
# Heating features                7165
# Cooling features               11782
# Appliances included            13442
# Laundry features               14124
# Parking features                4308
# Tax assessed value              3652
# Annual tax amount               4310
# Listed On                          0
# Listed Price                       0
# Last Sold On                   17766
# Last Sold Price                17766
# City                               0
# Zip                                0
# State                              0
# dtype: int64

# %%
test.isna().sum(axis = 0)
# Out:
# Id                                 0
# Address                            0
# Summary                          489
# Type                               0
# Year built                       897
# Heating                         5048
# Cooling                         4487
# Parking                          768
# Lot                             8808
# Bedrooms                        1726
# Bathrooms                       1945
# Full bathrooms                  5063
# Total interior livable area     1352
# Total spaces                     751
# Garage spaces                    750
# Region                             0
# Elementary School               3751
# Elementary School Score         3839
# Elementary School Distance      3751
# Middle School                  11573
# Middle School Score            11574
# Middle School Distance         11573
# High School                     2174
# High School Score               2565
# High School Distance            2174
# Flooring                       10363
# Heating features                5383
# Cooling features                4851
# Appliances included             9907
# Laundry features                5858
# Parking features                2320
# Tax assessed value              2671
# Annual tax amount               2899
# Listed On                          0
# Listed Price                       0
# Last Sold On                   11779
# Last Sold Price                11779
# City                               0
# Zip                                0
# State                              0
# dtype: int64

# %%
msno.matrix(train)
# Out:
# <AxesSubplot:>

# %%
msno.bar(test)
# Out:
# <AxesSubplot:>

# %%
array = train['Region'].unique()

print(len(array))
print(array)
# Out:
# 950
# ['Los Altos' 'Los Angeles' 'Strawberry' 'Culver City' 'Creston' 'Stockton'
#  'Taylorsville' 'San Francisco' 'Aptos' 'Santa Clara' 'San Jose'
#  'Snelling' 'Sunnyvale' 'San Mateo' 'Compton' 'Carlotta' 'San Carlos'
#  'Mountain View' 'Beverly Hills' 'Capitola' 'Los Gatos' 'West Hollywood'
#  'Santa Cruz' 'Foster City' 'Cupertino' 'Watsonville' 'San Bruno' 'Urban'
#  'Commerce' 'Redwood City' 'Milpitas' 'Saratoga' 'Lockwood' 'Freedom'
#  'Ben Lomond' 'Cudahy' 'Palo Alto' 'Menlo Park' 'Montara' 'Loleta'
#  'Atherton' 'Campbell' 'Los Olivos' 'Wallace' 'Patagonia' 'East Palo Alto'
#  'Zamora' 'Pacifica' 'Manton' 'Loma Mar' 'Coleville' 'Belmont' 'Default'
#  'Le Grand' 'Playa Vista' 'Point Reyes Station' 'South San Francisco'
#  'San Simeon' 'Redway' 'Boulder Creek' 'Los Altos Hills' 'San Martin'
#  'Woodside' 'Albion' 'Bradbury' 'Mt Baldy' 'Bell' 'Millbrae'
#  'Clipper Mills' 'Tubac' 'Moss Beach' 'Heber' 'Soquel' 'Royal Oaks'
#  'Half Moon Bay' 'Felton' 'Bakersfield' 'Nogales' 'Bolinas' 'Big Sur'
#  'Whitmore' 'Richvale' 'Santa Monica' 'Westchester' 'Fontana' 'Brookdale'
#  'Westport' 'Emerald Hills' 'French Gulch' 'June Lake' 'North San Juan'
#  'Bridgeport' 'Scotts Valley' 'Rural' 'Gold Run' 'Doyle' 'Miranda' 'Canby'
#  'San Bernardino' 'Stirling City' 'Mount Hermon' 'La Selva Beach'
#  'French Camp' 'Glencoe' 'Clements' nan 'Palermo' 'View Park' 'Isleton'
#  'Glassell Park' 'Byron' 'Bell Gardens' 'Standish' 'La Honda'
#  'Mokelumne Hill' 'Chilcoot' 'Rancho Dominguez' 'Rio Rico' 'Planada'
#  'Corralitos' 'Palomar Mountain' 'Inverness' 'Brisbane' 'Portola Valley'
#  'Pine Mountain Club' 'Fields Landing' 'Gasquet' 'Hydesville' 'Rimforest'
#  'Kenwood' 'Monte Sereno' 'Midpines' 'Terra Bella' 'Sheridan' 'Hornbrook'
#  'Somis' 'Brownsville' 'Forbestown' 'Stevinson' 'Santa Ysabel' 'Dunlap'
#  'Ross' 'Orosi' 'Walnut Grove' 'Fort Jones' 'Amador City' 'Oregon House'
#  'New Cuyama' 'Rough And Ready' 'Occidental' 'Greenwood' 'Glendale'
#  'Bonny Doon' 'Sonoita' 'Sacramento' 'Moss Landing' 'Eagle Rock' 'Shasta'
#  'Beckwourth' 'Jenner' 'Wishon' 'Raymond' 'Del Rey' 'Potrero' 'Sunol'
#  'Manchester' 'Piru' 'Orick' 'Ivanhoe' 'Downey' 'Alta' 'Lytle Creek'
#  'Fiddletown' 'Grenada' 'Angwin' 'Vallejo' 'Dutch Flat' 'San Lucas' 'Onyx'
#  'Herald' 'Yosemite National Park' 'Dillon Beach' 'Caruthers' 'Dunnigan'
#  'Potter Valley' 'Bangor' 'Rancho Park' 'El Granada' 'Orleans'
#  'Meadow Valley' 'Spreckels' 'Keene' 'Woodacre' 'Cutler' 'Stonyford'
#  'Millville' 'Graton' 'Esparto' 'Burnt Ranch' 'Lee Vining' 'Blue Lake'
#  'Miramonte' 'Yorkville' 'Midway City' 'Guinda' 'Cedarville' 'Armona'
#  'Dos Rios' 'Bella Vista' 'Etna' 'Bieber' 'Kettenpom' 'Dorris' 'Stanford'
#  'Hickman' 'Bridgeville' 'Elk' 'Klamath' 'Wilseyville' 'Pixley'
#  'Hollywood' 'Firebaugh' 'Igo' 'Laytonville' 'Catheys Valley' 'Pilot Hill'
#  'Junction City' 'Fall River Mills' 'Nicasio' 'San Geronimo' 'Elgin'
#  'Covelo' 'Paynes Creek' 'Glenn' 'Berkeley' 'Los Alamos' 'Tecate'
#  'Milford' 'Tranquillity' 'Calpine' 'Mad River' 'Branscomb' 'Bayside'
#  'Calipatria' 'Summerland' 'Avalon' 'Earlimart' 'Pinecrest'
#  'Forest Knolls' 'Geyserville' 'Oak Run' 'Foothill' 'Lotus' 'Vacaville'
#  'Strathmore' 'Applegate' 'Rail Road Flat' 'Olancha' 'Klamath River'
#  'Gonzales' 'Huron' 'Dinuba' 'Thornton' 'Pope Valley' 'Oro Grande'
#  'Madison' 'Ducor' 'Traver' 'Pescadero' 'Big River' 'Cty Of Cmmrce'
#  'Pleasant Grove' 'Nicolaus' 'Badger' 'Kneeland' 'Elk Creek' 'Durham'
#  'Laton' 'Philo' 'Hayfork' 'Meridian' 'Posey' 'Seiad Valley' 'Maxwell'
#  'Princeton' 'Pima County' 'Smith River' 'Hawkins Bar' 'Port Costa'
#  'Smartsville' 'Gilroy' 'Rumsey' 'Willow Creek' 'Point Arena'
#  'Witter Springs' 'Gorman' 'Hopland' 'Richgrove' 'Tumacacori' 'Capay'
#  'Chualar' 'Montgomery Creek' 'Hamilton City' 'Salyer' 'Marshall' 'Tipton'
#  'Ballico' 'Morgan Hill' 'Lamont' 'Buttonwillow' 'Arbuckle' 'Diablo'
#  'Oroville' 'Lebec' 'Dobbins' 'King City' 'Platina' 'Old Station' 'Yermo'
#  'Pala' 'Stinson Beach' 'Biggs' 'Riverdale' 'Sutter' 'Topaz' 'Big Pine'
#  'Mc Farland' 'Callahan' 'Rio Oso' 'Marysville' 'Maywood' 'Crescent City'
#  'Lewiston' 'Mill Creek' 'Earp' 'Penngrove' 'Tomales' 'Weott'
#  'Crows Landing' 'Kirkwood' 'Honeydew' 'Prather' 'Camarillo' 'Ahwahnee'
#  'Ryde' 'Playa Del Rey' 'Cassel' 'Williams' 'Scotia' 'Grimes' 'Mountain'
#  'Alpaugh' 'Lagunitas' 'Little River' 'Happy Camp' 'Mccloud' 'Caspar'
#  'Davenport' 'Burbank' 'Mendota' 'Hat Creek' 'Plymouth' 'Niland'
#  'Three Rivers' 'Tulelake' 'Sierraville' 'Windsor Hills' 'The Sea Ranch'
#  'Aromas' 'Big Oak Valley' 'Pinedale' 'Benton' 'Dulzura' 'San Ardo'
#  'Calif Hot Spirings' 'Monte Rio' 'Canyon Dam' 'Markleeville' 'Greenview'
#  'Paicines' 'Alviso' 'Shandon' 'Yountville' 'Cantua Creek' 'Butte Valley'
#  'Cazadero' 'Lakeport' 'Vina' 'Sierra City' 'Mcfarland' 'Walker' 'Bodfish'
#  'Downieville' 'Myers Flat' 'California City' 'Weaverville' 'Courtland'
#  'Camptonville' 'Mcarthur' 'North Palm Springs' 'Greenville' 'Keyes'
#  'Trinity Center' 'Woodlake' 'Gerber' 'Woodbridge' 'Ferndale' 'Colusa'
#  'Linden' 'Butte Meadows' 'Trinidad' 'Floriston' 'Tres Pinos'
#  'Pine Valley' 'Smartville' 'Echo Lake' 'California Hot Springs'
#  'Camp Meeker' 'Fulton' 'Penryn' 'Lakehead' 'Maricopa' 'Pt Arena' 'Arvin'
#  'Kelseyville' 'Crockett' 'Knightsen' 'Glennville' 'Hathaway Pines'
#  'Duncans Mills' 'Westmorland' 'Dunsmuir' 'Gazelle' 'Forest Ranch'
#  'Valley Springs' 'Twin Bridges' 'Petrolia' 'Tehama' 'Lockeford'
#  'Paso Robles' 'Castroville' 'Garberville' 'Douglas City' 'Farmersville'
#  'Saint Helena' 'Descanso' 'Angelus Oaks' 'Vernalis' 'Holtville' 'Vernon'
#  'Jacumba' 'Sonora' 'Guerneville' 'Glen Ellen' 'Fresno' 'Round Mountain'
#  'Challenge' 'Avenal' 'San Andreas' 'Mather' 'Bethel Island' 'Berry Creek'
#  'Wheatland' 'Madeline' 'Trona' 'Herlong' 'Shaver Lake' 'Knights Landing'
#  'Navarro' 'Mecca' 'Litchfield' 'Boonville' 'Glenhaven' 'Santa Rosa'
#  'Railroad Flat' 'Fish Camp' 'El Nido' 'Palomar Park' 'Lake City'
#  'Silverado' 'Finley' 'Point Reyes' 'Virginia Lakes' 'Coffee Creek'
#  'Los Molinos' 'Forest Falls' 'Skyforest' 'Inyokern' 'Victorville'
#  'Boulevard' 'Montrose' 'North Edwards' 'Browns Valley' 'Inglewood'
#  'Farmington' 'Orange Cove' 'Silverado Canyon' 'Mineral' 'West Point'
#  'Independence' 'Wilton' 'Westley' 'Delhi' 'Montebello' 'Friant'
#  'Tollhouse' 'Davis Creek' 'Alderpoint' 'Garden Valley' 'East Nicolaus'
#  'Big Bend' 'Burson' 'Twin Lakes' 'Caliente' 'Newport Beach' 'Rio Dell'
#  'Samoa' 'Diamond Springs' 'San Diego' 'Mount Baldy' 'Patterson' 'Hood'
#  'Parlier' 'Kernville' 'Volcano' 'Ranchita' 'Ione' 'Columbia' 'Bodega'
#  'Boron' 'Deer Park' 'Loyalton' 'Whitewater' 'Soledad' 'Pauma Valley'
#  'Elmira' 'Guadalupe' 'Sheep Ranch' 'Mountain Ranch' 'Weldon' 'Upper Lake'
#  'Elverta' 'Georgetown' 'Francisco' 'Napa' 'Mendocino' 'Yolo' 'Guatay'
#  'Bodega Bay' 'Redwood Valley' 'Desert Hot Springs' 'Santa Fe Springs'
#  'Coulterville' 'Winton' 'Vallecito' 'El Dorado' 'Janesville'
#  'South Dos Palos' 'Artesia' 'Stratford' 'Warner Springs' 'Hilmar'
#  'Frost Ct' 'Nice' 'Oak View' 'Ridgecrest' 'Loch Lomond' 'Middletown'
#  'Quincy' 'Cobb' 'Bass Lake' 'Fowler' 'Murphys' 'Dos Palos' 'Lucerne'
#  'Cabazon' 'Clio' 'Campo' 'Calistoga' 'Norden' 'Desert Center' 'Lennox'
#  'Larkspur' 'Lower Lake' 'Gustine' 'Baker' 'Petaluma' 'Lindsay' 'Fairfax'
#  'Winterhaven' 'Buellton' 'West Pt' 'Auberry' 'Tahoma' 'Avila Beach'
#  'Emigrant Gap' 'San Joaquin' 'Gridley' 'Burney' 'Palo Cedro' 'Rescue'
#  'Hawaiian Gardens' 'Cedar Glen' 'La Palma' 'Soda Springs' 'Bradley'
#  'Fremont' 'Brea' 'Rimrock' 'Oakland' 'Wasco' 'Ventura' 'Gualala'
#  'Somerset' 'Hughson' 'South Lake Tahoe' 'Denair' 'Balboa Island'
#  'San Ysidro' 'Live Oak' 'Raisin City' 'Livingston' 'Soulsbyville'
#  'Phillipsville' 'Annapolis' 'Gardena' 'Macdoel' 'Long Barn' 'North Fork'
#  'Galt' 'Winters' 'Acampo' 'El Monte' 'Pioneertown' 'Cool'
#  'Rancho Murieta' 'Cold Springs' 'Spring Valley' 'Wendel' 'Newcastle'
#  'River Pines' 'Kings Canyon National Pk' 'Green Acres' 'Angels Camp'
#  'Pearsonville' 'Camino' 'Squaw Valley' 'Biola' 'Cotati' 'Greenfield'
#  'Alturas' 'Waterford' 'Rio Linda' 'Mountain Center' 'Homewood'
#  'West Sacramento' 'Pine Grove' 'Colfax' 'Belden' 'Fawnskin' 'San Marino'
#  'Corte Madera' 'Montague' 'Fort Bidwell' 'Julian' 'Springville' 'Kerman'
#  'Mount Shasta' 'Redding' 'Mi Wuk Village' 'Lost Hills' 'Orange' 'Modesto'
#  'Castella' 'Lake Arrowhead' 'La Grange' 'Ukiah' 'Alhambra' 'Clarksburg'
#  'Green Valley Lake' 'Rio Nido' 'Homeland' 'San Juan Bautista' 'Greenbrae'
#  'Blythe' 'Sonoma' 'Grizzly Flats' 'Corcoran' 'Kensington' 'Cayucos'
#  'Villa Park' 'Rodeo' 'Salida' 'Kentfield' 'Green Valley' 'Forestville'
#  'Pt Reyes Station' 'Clearlake Oaks' 'Garden Grove' 'Albany'
#  'Carmel Valley' 'Oceano' 'Willows' 'Rio Vista' 'Santa Barbara' 'Hinkley'
#  'Sutter Creek' 'Newman' 'Wofford Heights' 'Meadow Vista' 'Sattley'
#  'Yreka' 'Sierra Madre' 'Sausalito' 'Truckee' 'Cedarpines Park' 'Avery'
#  'Santa Margarita' 'Vail' 'Red Bluff' 'Valley Center' 'Tuolumne' 'Havilah'
#  'Jamul' 'Cloverdale' 'Coalinga' 'Highland Park' 'Hornitos' 'W Hollywood'
#  'Weed' 'Calexico' 'Carmel By The Sea' 'Sea Ranch' 'Mt Madonna'
#  'Grand Terrace' 'Santa Ynez' 'Mission Hills' 'Crestline' 'Needles'
#  'Escalon' 'Pasadena' 'San Fernando' 'La Puente' 'Lemon Cove'
#  'Rancho Santa Fe' 'Fillmore' 'Kingsburg' 'Hoopa' 'Tracy' 'East Quincy'
#  'Lakewood' 'Castro Valley' 'Richmond' 'Lake Isabella' 'San Gabriel'
#  'Irvine' 'Fort Bragg' 'San Miguel' 'San Anselmo' 'Reedley'
#  'Blairsden Graeagle' 'Bonsall' 'Delano' 'Solvang' 'Jamestown'
#  'Amargosa Valley' 'Mentone' 'Nuevo' 'Ojai' 'Twin Peaks' 'Willits'
#  'Canoga Park' 'Woodland Hills' 'American Canyon' 'Lynwood' 'Alameda'
#  'Brawley' 'Duarte' 'Temecula' 'Tiburon' 'Swall Meadows' 'Foresthill'
#  'Shafter' 'Bishop' 'Graeagle' 'Pomona' 'Paramount' 'Lake Almanor'
#  'Chester' 'Bassett' 'Van Nuys' 'Novato' 'Huntington Park' 'Carnelian Bay'
#  'Signal Hill' 'Tahoe Vista' 'West Covina' 'Pearblossom' 'Llano'
#  'Pebble Beach' 'Jackson' 'Blairsden' 'El Segundo' 'Monterey Park'
#  'Lake Hughes' 'Whitethorn' 'Kings Beach' 'Exeter' 'Mojave' 'Riverbank'
#  'Chula Vista' 'Carson' 'Yuba City' 'Dana Pt' 'Davis' 'Covina' 'Belvedere'
#  'San Leandro' 'Healdsburg' 'Zenia' 'Tahoe City' 'Bonita' 'Wilmington'
#  'Hayward' 'Whittier' 'Rialto' 'Long Beach' 'Orland' 'Shingletown'
#  'Cardiff' 'Old' 'Torrance' 'Shelter Cove' 'Lawndale' 'Carpinteria'
#  'El Cerrito' 'Grass Valley' 'Rosamond' 'Elizabeth Lake' 'Salinas'
#  'Rosemead' 'Capistrano Beach' 'Topanga' 'Anaheim' 'Penn Valley'
#  'Fullerton' 'Orangevale' 'Pollock Pines' 'Santa Maria' 'Morongo Valley'
#  'Sherman Oaks' 'San Rafael' 'Sun Valley' 'Glendora' 'San Quentin'
#  'Oak Park' 'Dixon' 'Linda' 'Los Osos' 'Seaside' 'Sloughhouse'
#  'Sebastopol' 'Corning' 'Arcata' 'Portola' 'Clayton' 'Newberry Springs'
#  'Grover Beach' 'Belvedere Tiburon' 'Santa Ana' 'South Pasadena' 'Pinole'
#  'North Hollywood' 'Sugarloaf' 'Encino' 'Malibu' 'Lomita' 'Orinda'
#  'Bloomington' 'Porterville' 'Pioneer' 'Citrus Heights' 'Westwood' 'Ceres'
#  'Pismo Beach' 'Taft' 'Newport Coast' 'Santa Paula' 'Markleeville Ca'
#  'South El Monte' 'Woodland' 'Turlock' 'Loomis' 'Selma' 'Wrightwood'
#  'Del Mar' 'Montclair' 'North Highlands' 'Buena Park' 'Mckinleyville'
#  'El Centro' 'Morro Bay' 'Hercules' 'Chino' 'Cambria' 'Cerritos'
#  'Oceanside' 'Solana Beach' 'San Luis Obispo' 'Aguanga' 'Loma Linda'
#  'Imperial' 'Frazier Park' 'Twain Harte' 'Sanger' 'Alpine Meadows'
#  'Goleta' 'Banta' 'Atwater' 'El Sobrante' 'Visalia' 'Fortuna'
#  'Shasta Lake' 'Rancho Cordova' 'Cromberg' 'Alamo' 'Templeton'
#  'Hermosa Beach' 'Pinon Hills' 'Oxnard' 'Coachella' 'Los Banos'
#  'Olympic Valley' 'Nevada City' 'Carmichael' 'Daly City' 'Merced'
#  'Chowchilla' 'Windsor' 'Northridge' 'Foothill Ranch' 'Copperopolis'
#  'Thermal' 'Valencia' 'Jonesville' 'Los Alamitos' 'Clovis' 'Anza' 'Empire'
#  'Elk Grove']

# %%
train.head()
# Out:
#    Id            Address  Sold Price  \
# 0   0        540 Pine Ln   3825000.0
# 1   1     1727 W 67th St    505000.0
# 2   2     28093 Pine Ave    140000.0
# 3   3  10750 Braddock Dr   1775000.0
# 4   4  7415 O Donovan Rd   1175000.0
#
#                                              Summary          Type  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...  SingleFamily
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...  SingleFamily
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...  SingleFamily
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...  SingleFamily
# 4  Beautiful 200 acre ranch land with several pas...    VacantLand
#
#    Year built                                       Heating  \
# 0      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1      1926.0                                   Combination
# 2      1958.0                                    Forced air
# 3      1947.0                                       Central
# 4         NaN                                           NaN
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                          Parking     Lot  \
# 0             Garage, Garage - Attached, Covered     1.0
# 1                       Detached Carport, Garage  4047.0
# 2                                       0 spaces  9147.0
# 3  Detached Carport, Driveway, Garage - Two Door     NaN
# 4                                       0 spaces     NaN
#
#                                             Bedrooms  Bathrooms  \
# 0  Ground Floor Bedroom, Master Bedroom on Ground...        0.0
# 1                                                  3        2.0
# 2                                                  2        3.0
# 3                                                  5        3.0
# 4                                                NaN        NaN
#
#    Full bathrooms  Total interior livable area  Total spaces  Garage spaces  \
# 0             NaN                          1.0           0.0            0.0
# 1             2.0                        872.0           1.0            1.0
# 2             1.0                       1152.0           0.0            0.0
# 3             3.0                       2612.0           0.0            0.0
# 4             NaN                          NaN           NaN            NaN
#
#         Region                  Elementary School  Elementary School Score  \
# 0    Los Altos       Santa Rita Elementary School                      7.0
# 1  Los Angeles   Raymond Avenue Elementary School                      3.0
# 2   Strawberry                                NaN                      NaN
# 3  Culver City         Farragut Elementary School                      9.0
# 4      Creston  Santa Margarita Elementary School                      6.0
#
#    Elementary School Distance              Middle School  Middle School Score  \
# 0                         0.4                        NaN                  NaN
# 1                         0.8    John Muir Middle School                  2.0
# 2                         NaN                        NaN                  NaN
# 3                         0.2  Culver City Middle School                  7.0
# 4                         8.5   Atascadero Middle School                  5.0
#
#    Middle School Distance                                        High School  \
# 0                     NaN                              Los Altos High School
# 1                     1.1  Augustus F. Hawkins High A Critical Design And...
# 2                     NaN                              Long Barn High School
# 3                     0.2                            Culver City High School
# 4                    10.2                             Atascadero High School
#
#    High School Score  High School Distance                Flooring  \
# 0                8.0                   1.3  Tile, Hardwood, Carpet
# 1                2.0                   1.3                     NaN
# 2                NaN                  10.1                     NaN
# 3                8.0                   0.2              Wood, Tile
# 4                6.0                  10.6                     NaN
#
#   Heating features                                   Cooling features  \
# 0  Forced air, Gas                                            Central
# 1      Combination  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2       Forced air                                                NaN
# 3          Central                                        Central Air
# 4              NaN                                                NaN
#
#                                  Appliances included  \
# 0  Dishwasher, Dryer, Garbage disposal, Microwave...
# 1                                                NaN
# 2                                                NaN
# 3                                         Dishwasher
# 4                                                NaN
#
#                           Laundry features  \
# 0  Washer / Dryer, Inside, In Utility Room
# 1                                   Inside
# 2                                      NaN
# 3                   Stackable, Upper Level
# 4                                      NaN
#
#                                 Parking features  Tax assessed value  \
# 0             Garage, Garage - Attached, Covered            886486.0
# 1                       Detached Carport, Garage            505000.0
# 2                                            NaN             49627.0
# 3  Detached Carport, Driveway, Garage - Two Door           1775000.0
# 4                                            NaN                 NaN
#
#    Annual tax amount   Listed On  Listed Price Last Sold On  Last Sold Price  \
# 0            12580.0  2019-10-24     4198000.0          NaN              NaN
# 1             6253.0  2019-10-16      525000.0   2019-08-30         328000.0
# 2              468.0  2019-08-25      180000.0          NaN              NaN
# 3            20787.0  2019-10-24     1895000.0   2016-08-30        1500000.0
# 4                NaN  2019-06-07     1595000.0   2016-06-27         900000.0
#
#           City    Zip State
# 0    Los Altos  94022    CA
# 1  Los Angeles  90047    CA
# 2   Strawberry  95375    CA
# 3  Culver City  90230    CA
# 4      Creston  93432    CA

# %% [markdown]
# #Removing non-relevant features

# %%
plt.figure(figsize = (12, 12))
seaborn.heatmap(train.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (12, 12))
seaborn.heatmap(test.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
columns_to_delete = ['Id',
                     'Address', 
                     'Summary', 
                     'Type', 
                     'Heating', 
                     'Cooling', 
                     'Parking', 
                     'Lot', 
                     'Bedrooms', 
                     'Bathrooms', 
                     'Full bathrooms', 
                     'Total spaces', 
                     'Garage spaces', 
                     'Elementary School', 
                     'Middle School', 
                     'High School', 
                     'Flooring', 
                     'Heating features', 
                     'Cooling features', 
                     'Appliances included', 
                     'Laundry features', 
                     'Parking features', 
                     'Listed On', 
                     'Last Sold On', 
                     'Zip',
                     'City',
                     'State',
                     'Elementary School Distance', 
                     'Middle School Distance', 
                     'High School Distance',
                     'Region',
                     'Year built',
                     'Total interior livable area',
                     'Annual tax amount']

# %%
train.drop(columns = columns_to_delete, inplace = True)
train
# Out:
#        Sold Price  Elementary School Score  Middle School Score  \
# 0       3825000.0                      7.0                  NaN
# 1        505000.0                      3.0                  2.0
# 2        140000.0                      NaN                  NaN
# 3       1775000.0                      9.0                  7.0
# 4       1175000.0                      6.0                  5.0
# ...           ...                      ...                  ...
# 47434    159000.0                      3.0                  NaN
# 47435    255000.0                      5.0                  6.0
# 47436   2300000.0                      7.0                  3.0
# 47437    500000.0                      7.0                  7.0
# 47438    760000.0                      9.0                  8.0
#
#        High School Score  Tax assessed value  Listed Price  Last Sold Price
# 0                    8.0            886486.0     4198000.0              NaN
# 1                    2.0            505000.0      525000.0         328000.0
# 2                    NaN             49627.0      180000.0              NaN
# 3                    8.0           1775000.0     1895000.0        1500000.0
# 4                    6.0                 NaN     1595000.0         900000.0
# ...                  ...                 ...           ...              ...
# 47434                3.0            125049.0      155000.0              NaN
# 47435                7.0             68924.0      295900.0              NaN
# 47436                7.0            578000.0     2295000.0        2150000.0
# 47437                8.0            484696.0      499888.0         500000.0
# 47438                9.0             49671.0      748000.0              NaN
#
# [47439 rows x 7 columns]

# %%
test.drop(columns = columns_to_delete, inplace = True)
test
# Out:
#        Elementary School Score  Middle School Score  High School Score  \
# 0                          8.0                  NaN                NaN
# 1                          6.0                  4.0                5.0
# 2                          8.0                  NaN                NaN
# 3                          8.0                  NaN                NaN
# 4                          4.0                  4.0                5.0
# ...                        ...                  ...                ...
# 31621                      5.0                  7.0                7.0
# 31622                      3.0                  6.0                NaN
# 31623                      8.0                  3.0                5.0
# 31624                      7.0                  4.0                6.0
# 31625                      7.0                  NaN                3.0
#
#        Tax assessed value  Listed Price  Last Sold Price
# 0                     NaN      799900.0         819000.0
# 1                521977.0      479950.0          15000.0
# 2                     NaN      839900.0              NaN
# 3                442800.0      809900.0         810000.0
# 4                965282.0     1095000.0        1041000.0
# ...                   ...           ...              ...
# 31621           4819317.0     8500000.0         895500.0
# 31622            296819.0      330000.0         328000.0
# 31623                 NaN      443000.0              NaN
# 31624            334277.0      445000.0         470000.0
# 31625            543150.0      559000.0         532500.0
#
# [31626 rows x 6 columns]

# %% [markdown]
# #Filling gaps

# %%
prop = 'Last Sold Price'

print(min(train[prop]))
print(max(train[prop]))
print(np.mean(train[prop]))
# Out:
# nan
# nan
# 807853.7111515519

# %%
train.isna().sum(axis = 0)
# Out:
# Sold Price                     0
# Elementary School Score     4896
# Middle School Score        16705
# High School Score           5219
# Tax assessed value          3652
# Listed Price                   0
# Last Sold Price            17766
# dtype: int64

# %%
train['Elementary School Score'].fillna(0, inplace = True)
train['Middle School Score'].fillna(0, inplace = True)
train['High School Score'].fillna(0, inplace = True)
train['Tax assessed value'].fillna(np.mean(train['Tax assessed value']), inplace = True)
train['Last Sold Price'].fillna(np.mean(train['Last Sold Price']), inplace = True)

# %%
train.isna().sum(axis = 0)
# Out:
# Sold Price                 0
# Elementary School Score    0
# Middle School Score        0
# High School Score          0
# Tax assessed value         0
# Listed Price               0
# Last Sold Price            0
# dtype: int64

# %%
msno.matrix(train)
# Out:
# <AxesSubplot:>

# %%
test.isna().sum(axis = 0)
# Out:
# Elementary School Score     3839
# Middle School Score        11574
# High School Score           2565
# Tax assessed value          2671
# Listed Price                   0
# Last Sold Price            11779
# dtype: int64

# %%
test['Elementary School Score'].fillna(0, inplace = True)
test['Middle School Score'].fillna(0, inplace = True)
test['High School Score'].fillna(0, inplace = True)
test['Tax assessed value'].fillna(np.mean(test['Tax assessed value']), inplace = True)
test['Last Sold Price'].fillna(np.mean(test['Last Sold Price']), inplace = True)

# %%
test.isna().sum(axis = 0)
# Out:
# Elementary School Score    0
# Middle School Score        0
# High School Score          0
# Tax assessed value         0
# Listed Price               0
# Last Sold Price            0
# dtype: int64

# %%
msno.matrix(test)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Standardization

# %%
train_columns = list(train.columns)
train_columns.pop(0)
train_columns
# Out:
# ['Elementary School Score',
#  'Middle School Score',
#  'High School Score',
#  'Tax assessed value',
#  'Listed Price',
#  'Last Sold Price']

# %%
scaler = StandardScaler()
train_matrix = scaler.fit_transform(train.drop(columns = ['Sold Price']))

train_processed = pd.DataFrame(train_matrix, columns = train_columns)
train_processed.insert(0, 'Sold Price', train['Sold Price'])
train_processed
# Out:
#        Sold Price  Elementary School Score  Middle School Score  \
# 0       3825000.0                 0.706819            -1.145188
# 1        505000.0                -0.805416            -0.480314
# 2        140000.0                -1.939592            -1.145188
# 3       1775000.0                 1.462937             1.181874
# 4       1175000.0                 0.328760             0.516999
# ...           ...                      ...                  ...
# 47434    159000.0                -0.805416            -1.145188
# 47435    255000.0                -0.049299             0.849436
# 47436   2300000.0                 0.706819            -0.147876
# 47437    500000.0                 0.706819             1.181874
# 47438    760000.0                 1.462937             1.514311
#
#        High School Score  Tax assessed value  Listed Price  Last Sold Price
# 0               0.947451            0.090058      1.096415     1.249669e-16
# 1              -1.290160           -0.252904     -0.300871    -5.151027e-01
# 2              -2.036030           -0.662292     -0.432116     1.249669e-16
# 3               0.947451            0.888848      0.220305     7.429898e-01
# 4               0.201581            0.000000      0.106179     9.891515e-02
# ...                  ...                 ...           ...              ...
# 47434          -0.917225           -0.594487     -0.441627     1.249669e-16
# 47435           0.574516           -0.644944     -0.388026     1.249669e-16
# 47436           0.574516           -0.187276      0.372474     1.440737e+00
# 47437           0.947451           -0.271158     -0.310424    -3.304680e-01
# 47438           1.320387           -0.662253     -0.216037     1.249669e-16
#
# [47439 rows x 7 columns]

# %%
train_processed.describe()
# Out:
#          Sold Price  Elementary School Score  Middle School Score  \
# count  4.743900e+04             4.743900e+04         4.743900e+04
# mean   1.296050e+06            -3.193147e-15         6.406852e-17
# std    1.694452e+06             1.000011e+00         1.000011e+00
# min    1.005000e+05            -1.939592e+00        -1.145188e+00
# 25%    5.650000e+05            -8.054161e-01        -1.145188e+00
# 50%    9.600000e+05            -4.929850e-02        -1.478761e-01
# 75%    1.525000e+06             7.068191e-01         8.494362e-01
# max    9.000000e+07             1.840995e+00         1.846748e+00
#
#        High School Score  Tax assessed value  Listed Price  Last Sold Price
# count       4.743900e+04        4.743900e+04  4.743900e+04     4.743900e+04
# mean       -6.081548e-17       -5.039639e-17 -2.980201e-16     2.091146e-16
# std         1.000011e+00        1.000011e+00  1.000011e+00     1.000011e+00
# min        -2.036030e+00       -7.069079e-01 -5.005921e-01    -8.671968e-01
# 25%        -5.442893e-01       -4.572364e-01 -2.820403e-01    -3.465698e-01
# 50%         2.015811e-01       -1.621034e-01 -1.395727e-01     1.249669e-16
# 75%         5.745163e-01        9.998983e-02  6.959939e-02     1.249669e-16
# max         1.693322e+00        4.055799e+01  1.526310e+02     9.574400e+01

# %%
test_columns = list(test.columns)
test_columns
# Out:
# ['Elementary School Score',
#  'Middle School Score',
#  'High School Score',
#  'Tax assessed value',
#  'Listed Price',
#  'Last Sold Price']

# %%
scaler = StandardScaler()
test_matrix = scaler.fit_transform(test)

test_processed = pd.DataFrame(test_matrix, columns = test_columns)
test_processed
# Out:
#        Elementary School Score  Middle School Score  High School Score  \
# 0                     1.129208            -1.099842          -2.244667
# 1                     0.375743             0.248307          -0.273855
# 2                     1.129208            -1.099842          -2.244667
# 3                     1.129208            -1.099842          -2.244667
# 4                    -0.377721             0.248307          -0.273855
# ...                        ...                  ...                ...
# 31621                -0.000989             1.259420           0.514470
# 31622                -0.754453             0.922382          -2.244667
# 31623                 1.129208            -0.088730          -0.273855
# 31624                 0.752475             0.248307           0.120308
# 31625                 0.752475            -1.099842          -1.062180
#
#        Tax assessed value  Listed Price  Last Sold Price
# 0                0.000000     -0.063775     5.592262e-01
# 1               -0.015152     -0.340925    -9.991770e-01
# 2                0.000000     -0.029126     2.256493e-16
# 3               -0.121377     -0.055112     5.417814e-01
# 4                0.579593      0.191850     9.895316e-01
# ...                   ...           ...              ...
# 31621            5.750230      6.606287     7.075071e-01
# 31622           -0.317228     -0.470816    -3.924852e-01
# 31623            0.000000     -0.372932     2.256493e-16
# 31624           -0.266974     -0.371200    -1.172448e-01
# 31625            0.013254     -0.272450     3.899681e-03
#
# [31626 rows x 6 columns]

# %%
test_processed.describe()
# Out:
#        Elementary School Score  Middle School Score  High School Score  \
# count             3.162600e+04         3.162600e+04       3.162600e+04
# mean             -1.048530e-15        -7.597989e-15      -5.773391e-15
# std               1.000016e+00         1.000016e+00       1.000016e+00
# min              -1.884649e+00        -1.099842e+00      -2.244667e+00
# 25%              -7.544528e-01        -1.099842e+00      -6.680171e-01
# 50%              -9.887043e-04        -8.872995e-02       1.203076e-01
# 75%               7.524754e-01         9.223823e-01       9.086324e-01
# max               1.882672e+00         2.270532e+00       1.696957e+00
#
#        Tax assessed value  Listed Price  Last Sold Price
# count        3.162600e+04  3.162600e+04     3.162600e+04
# mean        -7.082110e-18 -2.213530e-17     1.073699e-16
# std          1.000016e+00  1.000016e+00     1.000016e+00
# min         -7.154451e-01 -7.566725e-01    -1.028252e+00
# 25%         -4.308370e-01 -4.100846e-01    -4.099300e-01
# 50%         -1.798236e-01 -2.204758e-01     2.256493e-16
# 75%          6.702447e-02  6.538023e-02     2.256493e-16
# max          5.156407e+01  3.605812e+01     3.541239e+01

# %% [markdown]
# #Diagrams

# %%
plt.figure(figsize = (12, 12))
seaborn.heatmap(train_processed.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (12, 12))
seaborn.heatmap(test_processed.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Making training and testing datasets

# %%
y = train_processed['Sold Price']
x = train_processed.drop(columns = ['Sold Price'])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42, shuffle = True)

print(f'X train: {x_train.shape}')
print(f'Y train: {y_train.shape}')
print()
print(f'X test: {x_test.shape}')
print(f'Y test: {y_test.shape}')
# Out:
# X train: (37951, 6)
# Y train: (37951,)
#
# X test: (9488, 6)
# Y test: (9488,)

# %% [markdown]
# #Decision tree regressor

# %%
tree = DecisionTreeRegressor(criterion = 'squared_error')
tree.fit(x_train, y_train)
y_pred = tree.predict(x_test)

print(f'Coefficient of determination: {sklearn_metrics.r2_score(y_test, y_pred)}')
# Out:
# Coefficient of determination: 0.7214663036912702

# %% [markdown]
# 1.0 - perfect prediction, 0.0 - imperfect prediction. Can be negative

# %% [markdown]
# #Comparison between several methods

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR

models = [LinearRegression(), 
          RandomForestRegressor(n_estimators = 100, max_features = 'sqrt'),
          KNeighborsRegressor(n_neighbors = 6), 
          LinearSVR(max_iter = 10000), 
          DecisionTreeRegressor()]

# %%
results = pd.DataFrame()

for model in models:
  temp_result = {}
  model_name = str(model)
  model_name = model_name[:model_name.index('(')]
  temp_result['Model'] = model_name
  model.fit(x_train, y_train) 
  temp_result['R2'] = sklearn_metrics.r2_score(y_test, model.predict(x_test))
  results = results.append([temp_result])

results.set_index('Model', inplace = True)

plt.subplots(figsize = (10, 10))
results['R2'].plot(kind = 'bar', title = 'R2')
# Out:
# C:\Users\Dexp\AppData\Local\Temp\ipykernel_9004\1610978336.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append([temp_result])
# C:\Users\Dexp\AppData\Local\Temp\ipykernel_9004\1610978336.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append([temp_result])
# C:\Users\Dexp\AppData\Local\Temp\ipykernel_9004\1610978336.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append([temp_result])
# C:\Users\Dexp\AppData\Local\Temp\ipykernel_9004\1610978336.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append([temp_result])
# C:\Users\Dexp\AppData\Local\Temp\ipykernel_9004\1610978336.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append([temp_result])
# <AxesSubplot:title={'center':'R2'}, xlabel='Model'>

# %%
print(results[results.R2 == results.R2.max()])
# Out:
#                              R2
# Model
# RandomForestRegressor  0.760948

# %% [markdown]
# #Multilayer perceptron

# %%
perceptron = Sequential()

activation_function = 'relu'
perceptron.add(Dense(256, input_dim = x_train.shape[1], activation = activation_function))
perceptron.add(Dense(128, activation = activation_function))
perceptron.add(Dense(32, activation = activation_function))
perceptron.add(Dense(1))

perceptron.compile(loss = 'mean_squared_error', optimizer = 'adam')
perceptron.summary()

monitor = EarlyStopping(monitor = 'val_loss', min_delta = 1e-6, patience = 15, verbose = 1, mode = 'auto', restore_best_weights = True)

fit_data = perceptron.fit(x_train, y_train, validation_data = (x_test, y_test), verbose = 2, callbacks = [monitor], epochs = 1000)
history = fit_data.history

print()
mse = sklearn_metrics.mean_squared_error(perceptron.predict(x_test), y_test)
print(f'Final score (MSE): {mse}')
rmse = np.sqrt(mse)
print(f'Final score (RMSE): {rmse}')
print()

loss_values = history['loss']
validation_loss_values = history['val_loss']

plt.figure(figsize = (10, 10))
plt.plot(loss_values, label = 'loss values')
plt.plot(validation_loss_values, label = 'validation loss values')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1792
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 38,849
# Trainable params: 38,849
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1186/1186 - 4s - loss: 3068668149760.0000 - val_loss: 1506298953728.0000 - 4s/epoch - 4ms/step
# Epoch 2/1000
# 1186/1186 - 3s - loss: 1396146044928.0000 - val_loss: 1219320741888.0000 - 3s/epoch - 2ms/step
# Epoch 3/1000
# 1186/1186 - 3s - loss: 1276577710080.0000 - val_loss: 1206550659072.0000 - 3s/epoch - 2ms/step
# Epoch 4/1000
# 1186/1186 - 3s - loss: 1269559328768.0000 - val_loss: 1200631840768.0000 - 3s/epoch - 2ms/step
# Epoch 5/1000
# 1186/1186 - 3s - loss: 1246861197312.0000 - val_loss: 1197435650048.0000 - 3s/epoch - 2ms/step
# Epoch 6/1000
# 1186/1186 - 3s - loss: 1248492650496.0000 - val_loss: 1200298917888.0000 - 3s/epoch - 2ms/step
# Epoch 7/1000
# 1186/1186 - 3s - loss: 1226780704768.0000 - val_loss: 1200063512576.0000 - 3s/epoch - 2ms/step
# Epoch 8/1000
# 1186/1186 - 3s - loss: 1214593761280.0000 - val_loss: 1191080361984.0000 - 3s/epoch - 2ms/step
# Epoch 9/1000
# 1186/1186 - 3s - loss: 1212466069504.0000 - val_loss: 1192990081024.0000 - 3s/epoch - 2ms/step
# Epoch 10/1000
# 1186/1186 - 3s - loss: 1225967665152.0000 - val_loss: 1211845574656.0000 - 3s/epoch - 2ms/step
# Epoch 11/1000
# 1186/1186 - 3s - loss: 1201136074752.0000 - val_loss: 1231838248960.0000 - 3s/epoch - 2ms/step
# Epoch 12/1000
# 1186/1186 - 3s - loss: 1197205880832.0000 - val_loss: 1225445605376.0000 - 3s/epoch - 2ms/step
# Epoch 13/1000
# 1186/1186 - 3s - loss: 1194788913152.0000 - val_loss: 1221450530816.0000 - 3s/epoch - 2ms/step
# Epoch 14/1000
# 1186/1186 - 3s - loss: 1196156125184.0000 - val_loss: 1225945907200.0000 - 3s/epoch - 2ms/step
# Epoch 15/1000
# 1186/1186 - 3s - loss: 1197593853952.0000 - val_loss: 1228557910016.0000 - 3s/epoch - 2ms/step
# Epoch 16/1000
# 1186/1186 - 3s - loss: 1178459701248.0000 - val_loss: 1220253974528.0000 - 3s/epoch - 2ms/step
# Epoch 17/1000
# 1186/1186 - 3s - loss: 1184036683776.0000 - val_loss: 1232567664640.0000 - 3s/epoch - 2ms/step
# Epoch 18/1000
# 1186/1186 - 3s - loss: 1178499153920.0000 - val_loss: 1251765780480.0000 - 3s/epoch - 2ms/step
# Epoch 19/1000
# 1186/1186 - 3s - loss: 1184572637184.0000 - val_loss: 1257952247808.0000 - 3s/epoch - 2ms/step
# Epoch 20/1000
# 1186/1186 - 3s - loss: 1166014939136.0000 - val_loss: 1235713654784.0000 - 3s/epoch - 2ms/step
# Epoch 21/1000
# 1186/1186 - 3s - loss: 1177838551040.0000 - val_loss: 1240424120320.0000 - 3s/epoch - 2ms/step
# Epoch 22/1000
# 1186/1186 - 3s - loss: 1170910609408.0000 - val_loss: 1263741173760.0000 - 3s/epoch - 2ms/step
# Epoch 23/1000
# Restoring model weights from the end of the best epoch: 8.
# 1186/1186 - 3s - loss: 1164821004288.0000 - val_loss: 1245692166144.0000 - 3s/epoch - 2ms/step
# Epoch 23: early stopping
#
# 297/297 [==============================] - 1s 1ms/step
# Final score (MSE): 1191080427950.829
# Final score (RMSE): 1091366.312450054

# %% [markdown]
# #Predictions

# %%
def chart_regression(prediction, y, sort = True):
  t = pd.DataFrame({'prediction': prediction, 'y': y})
  if sort:
    t.sort_values(by = ['y'], inplace = True)
  plt.figure(figsize = (14, 14))
  plt.plot(t['prediction'].tolist(), label = 'prediction')
  plt.plot(t['y'].tolist(), label = 'expected')
  plt.ylabel('output')
  plt.legend()
  plt.show()

# %%
test_prediction = perceptron.predict(x_test)

chart_regression(test_prediction.flatten(), y_test)
# Out:
# 297/297 [==============================] - 0s 1ms/step

# %% [markdown]
# #Multilayer perceptron (Keras Tuner)

# %%
def build_model(hp):
  activation_function = hp.Choice('activation', values = ['relu', 'sigmoid', 'tanh', 'elu', 'selu'])    
  model = Sequential()
  model.add(Dense(units = hp.Int('units_input', min_value = 32, max_value = 512, step = 32), input_dim = x_train.shape[1], activation = activation_function))
  model.add(Dense(1))
  model.compile(loss = 'mean_squared_error', optimizer = 'adam')
  return model

# %%
tuner = RandomSearch(build_model, objective = 'val_loss', max_trials = 80, directory = 'test_directory')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh', 'elu', 'selu'], 'ordered': False}
# units_input (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}

# %%
tuner.search(x_train, y_train, batch_size = 256, epochs = 20, validation_split = 0.2)
# Out:
# Trial 59 Complete [00h 00m 09s]
# val_loss: 4153606930432.0
#
# Best val_loss So Far: 4120651759616.0
# Total elapsed time: 00h 09m 03s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in test_directory\untitled_project
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000027659AE0760>
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 512
# Score: 4120651759616.0
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 480
# Score: 4122502496256.0
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 448
# Score: 4124664922112.0
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 416
# Score: 4127259361280.0
# Trial summary
# Hyperparameters:
# activation: selu
# units_input: 512
# Score: 4130119876608.0
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 384
# Score: 4131145383936.0
# Trial summary
# Hyperparameters:
# activation: relu
# units_input: 352
# Score: 4134286131200.0
# Trial summary
# Hyperparameters:
# activation: selu
# units_input: 480
# Score: 4134970064896.0
# Trial summary
# Hyperparameters:
# activation: elu
# units_input: 480
# Score: 4136114061312.0
# Trial summary
# Hyperparameters:
# activation: elu
# units_input: 416
# Score: 4139340529664.0

# %%
models = tuner.get_best_models(num_models = 3)
models
# Out:
# [<keras.engine.sequential.Sequential at 0x27659d7a730>,
#  <keras.engine.sequential.Sequential at 0x27659d7a040>,
#  <keras.engine.sequential.Sequential at 0x27659dbba00>]

# %%
for model in models:
  model.summary()
  model.evaluate(x_test, y_test)
  print()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               3584
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________
# 297/297 [==============================] - 1s 1ms/step - loss: 4713675751424.0000
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 480)               3360
#
#  dense_1 (Dense)             (None, 1)                 481
#
# =================================================================
# Total params: 3,841
# Trainable params: 3,841
# Non-trainable params: 0
# _________________________________________________________________
# 297/297 [==============================] - 1s 1ms/step - loss: 4715365531648.0000
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 448)               3136
#
#  dense_1 (Dense)             (None, 1)                 449
#
# =================================================================
# Total params: 3,585
# Trainable params: 3,585
# Non-trainable params: 0
# _________________________________________________________________
# 297/297 [==============================] - 0s 1ms/step - loss: 4717289144320.0000

# %% [markdown]
# #Making file with predictions

# %%
final_prediction = perceptron.predict(test_processed)
final_prediction = final_prediction.flatten()

final_prediction
# Out:
# 989/989 [==============================] - 1s 1ms/step
# array([1301842.  ,  879782.06, 1191398.6 , ..., 1177491.4 ,  970837.3 ,
#        1116325.2 ], dtype=float32)

# %%
final_prediction = models[1].predict(test_processed) #random forest regression
final_prediction
# Out:
# 989/989 [==============================] - 1s 1ms/step
# array([[ 878.0054 ],
#        [1719.7736 ],
#        [ 860.22577],
#        ...,
#        [6149.5586 ],
#        [6111.5723 ],
#        [ 718.897  ]], dtype=float32)

# %%
indexes = []
for i in range(0, len(test_processed)):
    indexes.append(i)

len(indexes)
# Out:
# 31626

# %%
test_processed2 = test_processed.copy(deep = True)
test_processed2['Id'] = indexes
test_processed2
# Out:
#        Elementary School Score  Middle School Score  High School Score  \
# 0                     1.129208            -1.099842          -2.244667
# 1                     0.375743             0.248307          -0.273855
# 2                     1.129208            -1.099842          -2.244667
# 3                     1.129208            -1.099842          -2.244667
# 4                    -0.377721             0.248307          -0.273855
# ...                        ...                  ...                ...
# 31621                -0.000989             1.259420           0.514470
# 31622                -0.754453             0.922382          -2.244667
# 31623                 1.129208            -0.088730          -0.273855
# 31624                 0.752475             0.248307           0.120308
# 31625                 0.752475            -1.099842          -1.062180
#
#        Tax assessed value  Listed Price  Last Sold Price     Id
# 0                0.000000     -0.063775     5.592262e-01      0
# 1               -0.015152     -0.340925    -9.991770e-01      1
# 2                0.000000     -0.029126     2.256493e-16      2
# 3               -0.121377     -0.055112     5.417814e-01      3
# 4                0.579593      0.191850     9.895316e-01      4
# ...                   ...           ...              ...    ...
# 31621            5.750230      6.606287     7.075071e-01  31621
# 31622           -0.317228     -0.470816    -3.924852e-01  31622
# 31623            0.000000     -0.372932     2.256493e-16  31623
# 31624           -0.266974     -0.371200    -1.172448e-01  31624
# 31625            0.013254     -0.272450     3.899681e-03  31625
#
# [31626 rows x 7 columns]

# %%
submission = pd.DataFrame({'Id': [x for x in range(len(test_processed))], 'Sold Price': np.squeeze(np.asarray(final_prediction))})
submission.to_csv('my_submission.csv', index = False)

my_submission = pd.read_csv('my_submission.csv')
my_submission
# Out:
#           Id   Sold Price
# 0          0    878.00540
# 1          1   1719.77360
# 2          2    860.22577
# 3          3    864.66394
# 4          4   7922.84600
# ...      ...          ...
# 31621  31621  52440.74600
# 31622  31622    602.15106
# 31623  31623   6149.55860
# 31624  31624   6111.57230
# 31625  31625    718.89700
#
# [31626 rows x 2 columns]
