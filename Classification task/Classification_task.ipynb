# %% [markdown]
# #Connecting libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# #Loading the dataset

# %%
d = pd.read_csv("adult.csv")
d
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# #Dataset info

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
d.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
d.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Length: 48842, dtype: bool

# %%
d.duplicated().sum()
# Out:
# 52

# %%
d[d.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25189   29                 ?   41281     Bachelors               13
# ...

# %%
d.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
d.isna().sum(axis = 0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# #Diagrams

# %% [markdown]
# ###Distribution by age and income

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(data = d[['age', 'income']], x = 'age', hue = 'income')

# %% [markdown]
# ###Distribution by income and level of education

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(data = d[['educational-num', 'income']], x = 'educational-num', hue = 'income')

# %% [markdown]
# ###Distribution by gender and level of education

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(data = d[['educational-num', 'gender']], x = 'educational-num', hue = 'gender')

# %% [markdown]
# ###Income distribution by age

# %%
seaborn.boxplot(data = d, x = 'income', y = 'age')

# %% [markdown]
# ###Income distribution by level of education

# %%
seaborn.boxplot(data = d, x = 'income', y = 'educational-num')

# %% [markdown]
# ###Work hours distrbution by gender

# %%
seaborn.boxplot(data = d, x = 'hours-per-week', y = 'gender')

# %% [markdown]
# ###Work hours distrbution by marital status

# %%
seaborn.boxplot(data = d, x = 'hours-per-week', y = 'marital-status')

# %% [markdown]
# ###Income distribution by age

# %%
seaborn.violinplot(data = d, x = 'income', y = 'age')

# %% [markdown]
# ###Marital status distribution by age

# %%
plt.figure(figsize = (10, 7))
seaborn.violinplot(data = d, x = 'marital-status', y = 'age')

# %% [markdown]
# ###Race distribution by age

# %%
plt.figure(figsize = (10, 7))
seaborn.violinplot(data = d, x = 'race', y = 'age')

# %% [markdown]
# ###Education type distribution by work hours

# %%
plt.figure(figsize = (20, 14))
seaborn.violinplot(data = d, x = 'education', y = 'hours-per-week')

# %% [markdown]
# ###Level of education distribution by work hours and income

# %%
plt.figure(figsize = (10, 7))

seaborn.scatterplot(data = d, x = 'educational-num', y = 'hours-per-week', hue = 'income')

# %% [markdown]
# ###Level of education distribution by work hours and gender

# %%
plt.figure(figsize = (10, 7))
seaborn.scatterplot(data = d, x ='educational-num', y = 'hours-per-week', hue = 'gender')

# %% [markdown]
# ###Income distribution

# %%
d.groupby('income').count()
# Out:
#           age  workclass  fnlwgt  education  educational-num  marital-status  \
# income
# <=50K   37155      37155   37155      37155            37155           37155
# >50K    11687      11687   11687      11687            11687           11687
#
#         occupation  relationship   race  gender  capital-gain  capital-loss  \
# income
# <=50K        37155         37155  37155   37155         37155         37155
# >50K         11687         11687  11687   11687         11687         11687
#
#         hours-per-week  native-country
# income
# <=50K            37155           37155
# >50K             11687           11687

# %% [markdown]
# ###Distribution by income and gender

# %%
d.groupby(['income', 'gender']).count()
# Out:
#                  age  workclass  fnlwgt  education  educational-num  \
# income gender
# <=50K  Female  14423      14423   14423      14423            14423
#        Male    22732      22732   22732      22732            22732
# >50K   Female   1769       1769    1769       1769             1769
#        Male     9918       9918    9918       9918             9918
#
#                marital-status  occupation  relationship   race  capital-gain  \
# income gender
# <=50K  Female           14423       14423         14423  14423         14423
#        Male             22732       22732         22732  22732         22732
# >50K   Female            1769        1769          1769   1769          1769
#        Male              9918        9918          9918   9918          9918
#
#                capital-loss  hours-per-week  native-country
# income gender
# <=50K  Female         14423           14423           14423
#        Male           22732           22732           22732
# ...

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(d['gender'])

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(d['income'])

# %% [markdown]
# ###Distribution by native country

# %%
d['native-country'].unique()
# Out:
# array(['United-States', '?', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
plt.figure(figsize = (20, 14))
seaborn.histplot(d['native-country'])

# %% [markdown]
# #Removing unnesessary features

# %%
data = d.drop(columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'native-country'])

data
# Out:
#        age  fnlwgt  educational-num   race  gender  capital-gain  \
# 0       25  226802                7  Black    Male             0
# 1       38   89814                9  White    Male             0
# 2       28  336951               12  White    Male             0
# 3       44  160323               10  Black    Male          7688
# 4       18  103497               10  White  Female             0
# ...    ...     ...              ...    ...     ...           ...
# 48837   27  257302               12  White  Female             0
# 48838   40  154374                9  White    Male             0
# 48839   58  151910                9  White  Female             0
# 48840   22  201490                9  White    Male             0
# 48841   52  287927                9  White  Female         15024
#
#        capital-loss  hours-per-week income
# 0                 0              40  <=50K
# 1                 0              50  <=50K
# 2                 0              40   >50K
# ...

# %% [markdown]
# #Non-numeric features encoding

# %%
from sklearn.preprocessing import LabelEncoder

data_encoded = data.copy()

label_encoder = LabelEncoder()
data_encoded['gender'] = label_encoder.fit_transform(data_encoded['gender'])
data_encoded['income'] = label_encoder.fit_transform(data_encoded['income'])

data_encoded
# Out:
#        age  fnlwgt  educational-num   race  gender  capital-gain  \
# 0       25  226802                7  Black       1             0
# 1       38   89814                9  White       1             0
# 2       28  336951               12  White       1             0
# 3       44  160323               10  Black       1          7688
# 4       18  103497               10  White       0             0
# ...    ...     ...              ...    ...     ...           ...
# 48837   27  257302               12  White       0             0
# 48838   40  154374                9  White       1             0
# 48839   58  151910                9  White       0             0
# 48840   22  201490                9  White       1             0
# 48841   52  287927                9  White       0         15024
#
#        capital-loss  hours-per-week  income
# 0                 0              40       0
# 1                 0              50       0
# 2                 0              40       1
# ...

# %%
data_encoded['race'].unique()
# Out:
# array(['Black', 'White', 'Asian-Pac-Islander', 'Other',
#        'Amer-Indian-Eskimo'], dtype=object)

# %%
data_encoded = pd.get_dummies(data_encoded)

data_encoded
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7       1             0             0
# 1       38   89814                9       1             0             0
# 2       28  336951               12       1             0             0
# 3       44  160323               10       1          7688             0
# 4       18  103497               10       0             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12       0             0             0
# 48838   40  154374                9       1             0             0
# 48839   58  151910                9       0             0             0
# 48840   22  201490                9       1             0             0
# 48841   52  287927                9       0         15024             0
#
#        hours-per-week  income  race_Amer-Indian-Eskimo  \
# ...

# %% [markdown]
# #Classification

# %% [markdown]
# Notice: classes are not balanced

# %%
plt.figure(figsize = (10, 7))
seaborn.histplot(data_encoded['income'])

# %%
X = data_encoded.drop(columns = 'income')
Y = data_encoded['income']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42, shuffle = True)
X_train_, X_validation, Y_train_, Y_validation = train_test_split(X_train, Y_train, test_size = 0.05, random_state = 42)         

print(f'X train: {X_train_.shape}')
print(f'Y train: {Y_train_.shape}')
print()
print(f'X test: {X_test.shape}')
print(f'Y test: {Y_test.shape}')
print()
print(f'X validation: {X_validation.shape}')
print(f'Y validation: {Y_validation.shape}')
# Out:
# X train: (37119, 12)
# Y train: (37119,)
#
# X test: (9769, 12)
# Y test: (9769,)
#
# X validation: (1954, 12)
# Y validation: (1954,)

# %% [markdown]
# ###K-nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

knn = KNeighborsClassifier(n_neighbors = 20)
knn.fit(X_train, Y_train)

y_pred = knn.predict(X_test)

print(f'Accuracy score: {metrics.accuracy_score(Y_test, y_pred) * 100:.2f}')
print(f'f1 score: {metrics.f1_score(Y_test, y_pred) * 100:.2f}')
print()
print('Classification report:')
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy score: 80.43
# f1 score: 34.21
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.89      7479
#            1       0.81      0.22      0.34      2290
#
#     accuracy                           0.80      9769
#    macro avg       0.81      0.60      0.61      9769
# weighted avg       0.80      0.80      0.76      9769

# %% [markdown]
# ###Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier    

tree = DecisionTreeClassifier()
tree.fit(X_train, Y_train)
y_pred = tree.predict(X_test)

print(f'Accuracy score: {metrics.accuracy_score(Y_test, y_pred) * 100:.2f}')
print(f'f1 score: {metrics.f1_score(Y_test, y_pred) * 100:.2f}')
print()
print('Classification report:')
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy score: 78.60
# f1 score: 55.18
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      7479
#            1       0.54      0.56      0.55      2290
#
#     accuracy                           0.79      9769
#    macro avg       0.70      0.71      0.71      9769
# weighted avg       0.79      0.79      0.79      9769

# %% [markdown]
# ###Logistic regression

# %%
from sklearn.linear_model import LogisticRegression       

logit = LogisticRegression()
logit.fit(X_train, Y_train)
y_pred = logit.predict(X_test)

print(f'Accuracy score: {metrics.accuracy_score(Y_test, y_pred) * 100:.2f}')
print(f'f1 score: {metrics.f1_score(Y_test, y_pred) * 100:.2f}')
print()
print('Classification report:')
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy score: 80.38
# f1 score: 39.24
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88      7479
#            1       0.72      0.27      0.39      2290
#
#     accuracy                           0.80      9769
#    macro avg       0.76      0.62      0.64      9769
# weighted avg       0.79      0.80      0.77      9769

# %% [markdown]
# ###Multilayer perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical

Y_train_categorical = to_categorical(Y_train_)
Y_test_categorical  = to_categorical(Y_test)
Y_validation_categorical  = to_categorical(Y_validation)

perceptron = Sequential()
perceptron.add(Dense(50, input_dim = X_train.shape[1], activation = 'relu'))
perceptron.add(Dense(50, activation = 'relu'))
perceptron.add(Dense(50, activation = 'relu'))
perceptron.add(Dense(Y_train_categorical.shape[1], activation = 'sigmoid'))
perceptron.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

perceptron.summary()

perceptron.fit(X_train_, Y_train_categorical, validation_data = (X_validation, Y_validation_categorical), epochs = 15)

_, accuracy = perceptron.evaluate(X_test, Y_test_categorical)  

print()
print(f'Accuracy: {accuracy * 100:.2f}')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_39 (Dense)            (None, 50)                650
#
#  dense_40 (Dense)            (None, 50)                2550
#
#  dense_41 (Dense)            (None, 50)                2550
#
#  dense_42 (Dense)            (None, 2)                 102
#
# ...
# Total params: 5,852
# Trainable params: 5,852
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 1160/1160 [==============================] - 6s 4ms/step - loss: 136.0617 - accuracy: 0.6739 - val_loss: 49.6945 - val_accuracy: 0.7764
# Epoch 2/15
# 1160/1160 [==============================] - 3s 2ms/step - loss: 52.6193 - accuracy: 0.6819 - val_loss: 8.2136 - val_accuracy: 0.7339
# Epoch 3/15
# ...

# %% [markdown]
# #Results

# %% [markdown]
# * Accuracy of MLP with hyperparameters `epochs = 5` and layers `50, 50, 50` is 78.95
# * Accuracy of MLP with hyperparameters `epochs = 50` and layers `50, 50, 50` is 76.63
